# %%
input()
# Out:
# 123
# '123'

# %%
name = input()
# Out:
# marwa

# %%
print(name)
# Out:
# marwa

# %%
print('enter your age')
age = input()
# Out:
# enter your age
# 55

# %%
print('time to pension', 60-age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-7660050d99ec> in <cell line: 0>()
# ----> 1 print('time to pension', 60-age)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
age = input('Enter your age: ')
# Out:
# Enter your age: 35

# %%
age = int(age)
age = float(age)
print('time to pension', 60-age)
# Out:
# time to pension 25.0

# %%
age = int(input('enter your age: '))
print('time to pension', 60-age)
# Out:
# enter your age: 44
# time to pension 16

# %%
'ab' + 'yz'#concatenation operator
# Out:
# 'abyz'

# %%
2+3
# Out:
# 5

# %%
3+2
# Out:
# 5

# %%
'yz' + 'ab'
# Out:
# 'yzab'

# %%
'ab' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8f923bbcf74f> in <cell line: 0>()
# ----> 1 'ab' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %%
'ab' + '2'
# Out:
# 'ab2'

# %%
'2'*5#replication operator
# Out:
# '22222'

# %%
'abcd' * -2
# Out:
# ''

# %%
'abcd' * 0
# Out:
# ''

# %%
'abcd' * 2
# Out:
# 'abcdabcd'

# %%
int('25')
# Out:
# 25

# %%
str(25)
# Out:
# '25'

# %%
side1 = float(input('Enter the length of the first side'))
side2 = float(input('Enter the length of the second side'))
print('Hypotenuse length is:' + str((side1**2+side2**2)**0.5))
# Out:
# Enter the length of the first side3
# Enter the length of the second side4
# Hypotenuse length is:5.0

# %%
#lab2
width = int(input('Enter width of the rectangle'))#5
length = int(input('Enter length of the rectangle'))#3
'''
+-----+
|     |
|     |
|     |
|     |
|     |
|     |
|     |
+-----+
'''

# %%
#comparison operators: ==, !=, <=, <, >=, >

# %%
2==3
# Out:
# False

# %%
5>=4
# Out:
# True

# %%
x=3
print(x==0)
# Out:
# False

# %%
x*2 +3 ==10
# Out:
# False

# %%
#operator priorities
()
+- unary
**
* / // %
+ - binary
<,<=,>,>=
==,!=

# %%
if condition:
  do this if condition is true

# %%
x=3
if x==3:
  print('Three')
# Out:
# Three

# %%
if x==0:
  print('zero')

# %%
if x==0:  print('zero')

# %%
x=3
if x==3:
  print('Three')
  print('Bye')
# Out:
# Three
# Bye

# %%
color='red'
if color=='red':
  if x==3:
    print('abc')
  print('stop')
elif color=='yellow':
  print('wait')
elif color=='green':
  print('go')
else:
  print('error')

# %%
color='red'
if color=='red':
  if x==3: print('abc')
  print('stop')
elif color=='yellow': print('wait')
elif color=='green': print('go')
else: print('error')
# Out:
# abc
# stop

# %%
x=-3
if x:
  print('hello')
# Out:
# hello

# %%
x=0
if x:
  print('hello')
print('in main code')
# Out:
# in main code

# %%
x=''
if x:
  print('hello')
print('in main code')
# Out:
# in main code

# %%
x=None
if x:
  print('hello')
print('in main code')
# Out:
# in main code

# %%
x=0
if not x:
  print('hello')
print('in main code')
# Out:
# hello
# in main code

# %%
#logic operators: not, and, or

# %%
if x or color:
  print('hello')
# Out:
# hello

# %%
if (not x) and color:
  print('hello')
# Out:
# hello

# %%
while condition:
  repeat as long as condition is True

# %%
while not x:
  print('abc')

# %%
even=0
odd=0
number= int(input('Enter a number or 0 to stop:'))
while number !=0:#while number:
  if number%2:
    odd+=1
  else:
    even+=1
  number= int(input('Enter a number or 0 to stop:'))

print('# even:',even,'and #odd:',odd)
# Out:
# Enter a number or 0 to stop:12
# Enter a number or 0 to stop:-23
# Enter a number or 0 to stop:9
# Enter a number or 0 to stop:8
# Enter a number or 0 to stop:7
# Enter a number or 0 to stop:0
# # even: 2 and #odd: 3

# %%
counter=1
while counter<=5:
  print('loop number',counter)
  counter=counter+1
# Out:
# loop number 1
# loop number 2
# loop number 3
# loop number 4
# loop number 5

# %%
counter=5
while counter:
  print(counter)
  counter=counter-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range(5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(1,10,2):
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
for i in range(10,1,-1):
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %%
for i in range(1,1):
  print(i)

# %%
for i in range(10):
  if i==3:
    break
  print(i)
# Out:
# 0
# 1
# 2

# %%
counter=5
while counter:
  if counter==3:
    break
  print(counter)
  counter=counter-1
# Out:
# 5
# 4

# %%
for i in range(10):
  if not i%2:
    continue
  print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i=1
while i<5:
  print(i)
  i=i+1
else:
  print('else:',i)
# Out:
# 1
# 2
# 3
# 4
# else: 5

# %%
i=5
while i<5:
  print(i)
  i=i+1
else:
  print('else:',i)
# Out:
# else: 5

# %%
for i in range(5):
  print(i)
else:
  print('else:',i)
# Out:
# 0
# 1
# 2
# 3
# 4
# else: 4

# %%
i=111
for i in range(2,1):
  print(i)
else:
  print('else:',i)
# Out:
# else: 111

# %%
#lab3
'''
   =
  = =
 = = =
'''
height=0
blocks = int(input('ENter number of blocks'))

print('height of the pyramid is:',height)

# %%
while True:
  print('abc')
  if x==3:
    break
# Out:
# Streaming output truncated to the last 5000 lines.
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# abc
# ...
